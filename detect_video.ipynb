# %% [markdown]
# # **INFERENCE OVER VIDEO**
#
#  Realizado por: [Alejandro Sanchez Ferrer](mailto:alejandro_sanchez_ferrer@hotmail.com), [Antonio Javier Gallego](mailto:jgallego@dlsi.ua.es), Jorge Calvo Zaragoza & Jose Javier Valero Mas

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### Import dependencies

# %%
import os, sys
import sys
import random
import math
import numpy as np
import scipy.misc
import matplotlib
import matplotlib.pyplot as plt
import cv2
import json
from PIL import Image, ImageDraw
from tensorflow.python.framework.versions import VERSION as __version__
import tensorflow as tf
import imgaug

# %% [markdown]
# ### Add relevant paths

# %% [markdown]
# Add root directory for Mask-RCNN

# %%
#Cambiamos el Directorio al propio de MASK_RCNN
ROOT_DIR = os.getcwd()
assert os.path.exists(ROOT_DIR), 'ROOT_DIR does not exist'
sys.path.append(ROOT_DIR)

# %% [markdown]
# Add models folder

# %%
# Directorio perteneciente a MASK-RCNN
MODEL_DIR = os.path.join(ROOT_DIR, "models")
assert os.path.exists(MODEL_DIR), 'MODEL_DIR does not exist'

# %% [markdown]
# ### Add MASK-RCNN functions

# %% [markdown]
# Add specific functions of Mask-RCNN

# %%
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.

    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# ### Define MASK-RCNN Configuration

# %%
class CleanSeaConfig(Config):
    """
    Configuracion para el entrenamiento con CleanSea Dataset.
    """

    # Nombre de la configuracion
    NAME = "debris"

    # We use a GPU with 12GB memory, which can fit two images.
    # Adjust down if you use a smaller GPU.
    IMAGES_PER_GPU = 1

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512

    # Numero de clases + el background
    NUM_CLASSES = 1 + 19  # Cleansea tiene 19 clases

    # Salta las detecciones con <50% de seguridad
    DETECTION_MIN_CONFIDENCE = 0.5

# %%
config= CleanSeaConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.5
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                32
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           debris
# NUM_CLASSES                    20
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ### Dataset Configuration
# Add data & masks loading methods

# %%
class CleanSeaDataset(utils.Dataset):
    def load_data(self, dataset_dir, subset):
        # Train or validation dataset?
        assert subset in ["train_coco", "test_coco"]
        dataset_dir = os.path.join(dataset_dir, subset)
        print(dataset_dir)

        # Cargamos el archivo json
        annotation_json = os.path.join(dataset_dir,"annotations.json")
        json_file = open(annotation_json)
        coco_json = json.load(json_file)
        json_file.close()
        print("\nAnotaciones Cargadas\n")

        # Añadimos los nombres de las clases usando el metodo de utils.Dataset
        source_name = "coco_like"
        for category in coco_json['categories']:
            class_id = category['id']
            class_name = category['name']
            if class_id < 1:
                print('Error: Class id for "{}" reserved for the background'.format(class_name))
            else:
                self.add_class(source_name, class_id, class_name)
        print("Nombres Añadidos \n")

        # Almacenamos las anotaciones
        annotations = {}
        for annotation in coco_json['annotations']:
            image_id = annotation['image_id']
            if image_id not in annotations:
                annotations[image_id] = []
            annotations[image_id].append(annotation)
        print("Anotaciones Almacenadas\n")

        # Almacenamos las imagenes y las añadimos al dataset
        seen_images = {}
        for image in coco_json['images']:
            image_id = image['id']
            if image_id in seen_images:
                print("Warning: Skipping duplicate image id: {}".format(image))
            else:
                seen_images[image_id] = image
                try:
                    image_file_name = image['file_name']
                    image_width = image['width']
                    image_height = image['height']
                except KeyError as key:
                    print("Warning: Skipping image (id: {}) with missing key: {}".format(image_id, key))
                
                image_path = os.path.join(dataset_dir, image_file_name)
                image_annotations = annotations[image_id]
                
                # Añadimos la imagen usando el metodo de utils.Dataset
                self.add_image(
                    source=source_name,
                    image_id=image_id,
                    path=image_path,
                    width=image_width,
                    height=image_height,
                    annotations=image_annotations
                )
        print("Imagenes añadidas al Dataset\n")

    def load_mask(self, image_id):
        """ Carga la mascara de instancia para la imagen dada
        MaskRCNN espera mascaras en forma de mapa de bits (altura, anchura e instancias)
        Argumentos:
            image_id: El ID de la imagen a la que vamos a cargar la mascara
        Salida:
            masks: Una cadena booleana con estructura (altura, anchya y la cuenta de instancias) con una mascara por instancia
            class_ids: Una cadena de 1 dimension de clase ID de la instancia de la mascara """
        image_info = self.image_info[image_id]
        annotations = image_info['annotations']
        instance_masks = []
        class_ids = []
        
        for annotation in annotations:
            class_id = annotation['category_id']
            mask = Image.new('1', (image_info['width'], image_info['height']))
            mask_draw = ImageDraw.ImageDraw(mask, '1')
            for segmentation in annotation['segmentation']:
                mask_draw.polygon(segmentation, fill=1)
                bool_array = np.array(mask) > 0
                instance_masks.append(bool_array)
                class_ids.append(class_id)

        mask = np.dstack(instance_masks)
        class_ids = np.array(class_ids, dtype=np.int32)
        return mask, class_ids

    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if info["source"] == "object":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)

# %% [markdown]
# ### Add video inference utils functions

# %%
# define random colors
COLOR_CODE = [(255,0,0),(0,255,0),(0,0,255),(255,155,0),(255,155,155),(155,255,0),(155,255,155),(155,0,255),(155,155,255),(255,255,0),(0,255,255),(255,0,255)]

def random_colors(N):
  np.random.seed(1)
  colors = [tuple(255 * np.random.rand(3)) for _ in range(N)]
  return colors

#apply mask to image
def apply_mask(image, mask, color, alpha=0.5):
  for n, c in enumerate(color):
    image[:, :, n] = np.where(mask == 1, image[:, :, n] * (1-alpha) + alpha * c, image[:, :, n])
  return image

#take the image and apply the mask, box, and Label
def display_instances(image, boxes, masks, ids, names, scores, colors):
  n_instances = boxes.shape[0]
  #colors = random_colors(n_instances)
  if not n_instances:
    print("NO INSTANCES TO DISPLAY")
  else:
    assert boxes.shape[0] == masks.shape[-1] == ids.shape[0]
  for i in range(n_instances):
    if not np.any(boxes[i]):
      continue

    y1, x1, y2, x2 = boxes[i]
    label = names[ids[i]]
    score = scores[i] if scores is not None else None
    caption = "{} {:.2f}".format(label, score) if score else label
    mask = masks[:, :, i]
    color = colors[names.index(label)]

    image = apply_mask(image, mask, color)
    image = cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
    image = cv2.putText(image, caption, (x1, y1), cv2.FONT_HERSHEY_COMPLEX, 0.7, color, 2)
  return image

# %% [markdown]
# ## Video Paths

# %%
VIDEO_FILE = "../cleansea_dataset/Videos/video_analisis/debrisVideo_PRL2.mp4"
assert os.path.exists(VIDEO_FILE), "Chosen file does not exist"
VIDEO_SAVE_DIR = os.path.join(ROOT_DIR, 'detect')
assert os.path.exists(VIDEO_SAVE_DIR), os.makedirs(VIDEO_SAVE_DIR)
MODEL_PATH = os.path.join(MODEL_DIR, 'Mask_RCNN_Epoch-1000_Aug-severe_Size-100_Train-real_Fill-synth_Limit-False.h5')
assert os.path.exists(MODEL_PATH), "Chosen MODEL does not exist"

# %% [markdown]
# ## Inference

# %% [markdown]
# ### Inference configuration

# %%
class InferenceConfig(CleanSeaConfig):
  GPU_COUNT = 1
  IMAGES_PER_GPU = 3

batch_size = 3

# %%
config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     3
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.5
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 3
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                32
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           debris
# NUM_CLASSES                    20
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ### Class Names

# %%
class_names = ['BG','Can','Squared_Can','Wood','Bottle','Plastic_Bag','Glove','Fishing_Net','Tire','Packaging_Bag','WashingMachine','Metal_Chain','Rope','Towel','Plastic_Debris','Metal_Debris','Pipe','Shoe','Car_Bumper','Basket']

# %% [markdown]
# ### Load Model for inference

# %%
# Create model object in inference mode.
model = modellib.MaskRCNN(mode='inference', model_dir=MODEL_DIR, config=config)
# Load weights trained on MS-COCO
model.load_weights(MODEL_PATH, by_name=True)

# %% [markdown]
# ### Video creation function

# %%
def make_video(outvid, images=None, fps=30, size=None,
               is_color=True, format="FMP4"):
    """
    Create a video from a list of images.
 
    @param      outvid      output video
    @param      images      list of images to use in the video
    @param      fps         frame per second
    @param      size        size of each frame
    @param      is_color    color
    @param      format      see http://www.fourcc.org/codecs.php
    @return                 see http://opencv-python-tutroals.readthedocs.org/en/latest/py_tutorials/py_gui/py_video_display/py_video_display.html
 
    The function relies on http://opencv-python-tutroals.readthedocs.org/en/latest/.
    By default, the video will have the size of the first image.
    It will resize every image to this size before adding them to the video.
    """
    from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize
    fourcc = VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = resize(img, size)
        vid.write(img)
    vid.release()
    return vid

# %% [markdown]
# ### Video processing

# %% [markdown]
# #### Check CUDA Drivers

# %%
# !nvidia-smi
# Out:
# Sun Nov 27 00:44:09 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 526.98       Driver Version: 526.98       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   59C    P0    30W /  N/A |   7557MiB /  8192MiB |     21%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      6548    C+G   ...h8wxbdkxb8p\DCv2\DCv2.exe    N/A      |
# |    0   N/A  N/A     21044      C   ...\envs\cleansea\python.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #### Initialize GPU

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
os.environ["CUDA_VISIBLE_DEVICES"]="0"
print(physical_devices)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.test.is_built_with_cuda()
# Out:
# True

# %% [markdown]
# #### Process

# %%
video = cv2.VideoCapture(VIDEO_FILE)

# Find OpenCV version
(major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')
if int(major_ver) < 3 :
  fps = video.get(cv2.cv.CV_CAP_PROP_FPS)
  print('Frames per second using video.get(cv2.cv.CV_CAP_PROP_FPS): {0}'.format(fps))
else :
  fps = video.get(cv2.CAP_PROP_FPS)
  print("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(fps))

try:
  if not os.path.exists(VIDEO_SAVE_DIR):
    os.makedirs(VIDEO_SAVE_DIR)
except OSError:
  print ('Error: Creating directory of data')

frames = []
frame_count = 0
colors = random_colors(len(class_names))
while True:
  ret, frame = video.read() 
  if not ret:
    break

# Save each frame of the video to a list
  frame_count += 1
  frames.append(frame)
  print('Frames :{0}'.format(frame_count))
  
  if len(frames) == batch_size:
    results = model.detect(frames, verbose=0)
    print('Predicted')
    for i, item in enumerate(zip(frames, results)):
      frame = item[0]
      r = item[1]
      frame = display_instances(frame, r['rois'], r['masks'], r['class_ids'], class_names, r['scores'],colors)
      name = '{0}.jpg'.format(frame_count + i - 3)
      name = os.path.join(VIDEO_SAVE_DIR, name)
      cv2.imwrite(name, frame)
      print('writing to file:{0}'.format(name))
      # Clear the frames array to start the next batch
      frames = []
video.release()
# Out:
# Frames per second using video.get(cv2.CAP_PROP_FPS) : 30.0
# Frames :1
# Frames :2
# Frames :3
# Predicted
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\0.jpg
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\1.jpg
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\2.jpg
# Frames :4
# Frames :5
# Frames :6
# Predicted
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\3.jpg
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\4.jpg
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\5.jpg
# Frames :7
# Frames :8
# Frames :9
# Predicted
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\6.jpg
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\7.jpg
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8.jpg
# Frames :10
# Frames :11
# Frames :12
# Predicted
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (114.21284917485582, 231.69185328873937, 74.87160783528827)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\9.jpg
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\10.jpg
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\11.jpg
# Frames :13
# Frames :14
# Frames :15
# Predicted
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\12.jpg
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\13.jpg
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\14.jpg
# Frames :16
# Frames :17
# Frames :18
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\15.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (35.79866934178461, 50.51587971664409, 204.18986501226186)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\16.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\17.jpg
# Frames :19
# Frames :20
# Frames :21
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\18.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\19.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\20.jpg
# Frames :22
# Frames :23
# Frames :24
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\21.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\22.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\23.jpg
# Frames :25
# Frames :26
# Frames :27
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\24.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\25.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\26.jpg
# Frames :28
# Frames :29
# Frames :30
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\27.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\28.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\29.jpg
# Frames :31
# Frames :32
# Frames :33
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\30.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\31.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\32.jpg
# Frames :34
# Frames :35
# Frames :36
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\33.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\34.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\35.jpg
# Frames :37
# Frames :38
# Frames :39
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\36.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\37.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\38.jpg
# Frames :40
# Frames :41
# Frames :42
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\39.jpg
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\40.jpg
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\41.jpg
# Frames :43
# Frames :44
# Frames :45
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\42.jpg
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\43.jpg
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\44.jpg
# Frames :46
# Frames :47
# Frames :48
# Predicted
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\45.jpg
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\46.jpg
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\47.jpg
# Frames :49
# Frames :50
# Frames :51
# Predicted
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\48.jpg
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\49.jpg
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\50.jpg
# Frames :52
# Frames :53
# Frames :54
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\51.jpg
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\52.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\53.jpg
# Frames :55
# Frames :56
# Frames :57
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\54.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\55.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\56.jpg
# Frames :58
# Frames :59
# Frames :60
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\57.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\58.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\59.jpg
# Frames :61
# Frames :62
# Frames :63
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (47.49635390130608, 88.11798539597717, 101.17570592882083)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\60.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\61.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (170.96921509549256, 106.41272460361738, 142.46590625366667)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\62.jpg
# Frames :64
# Frames :65
# Frames :66
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\63.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\64.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\65.jpg
# Frames :67
# Frames :68
# Frames :69
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\66.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\67.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\68.jpg
# Frames :70
# Frames :71
# Frames :72
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\69.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\70.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\71.jpg
# Frames :73
# Frames :74
# Frames :75
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\72.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\73.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\74.jpg
# Frames :76
# Frames :77
# Frames :78
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\75.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\76.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\77.jpg
# Frames :79
# Frames :80
# Frames :81
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\78.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\79.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\80.jpg
# Frames :82
# Frames :83
# Frames :84
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\81.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\82.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\83.jpg
# Frames :85
# Frames :86
# Frames :87
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\84.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\85.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\86.jpg
# Frames :88
# Frames :89
# Frames :90
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\87.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\88.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\89.jpg
# Frames :91
# Frames :92
# Frames :93
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\90.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\91.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\92.jpg
# Frames :94
# Frames :95
# Frames :96
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\93.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\94.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\95.jpg
# Frames :97
# Frames :98
# Frames :99
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\96.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\97.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\98.jpg
# Frames :100
# Frames :101
# Frames :102
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\99.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\100.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\101.jpg
# Frames :103
# Frames :104
# Frames :105
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\102.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\103.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\104.jpg
# Frames :106
# Frames :107
# Frames :108
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\105.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\106.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\107.jpg
# Frames :109
# Frames :110
# Frames :111
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\108.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\109.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\110.jpg
# Frames :112
# Frames :113
# Frames :114
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\111.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\112.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\113.jpg
# Frames :115
# Frames :116
# Frames :117
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\114.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\115.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\116.jpg
# Frames :118
# Frames :119
# Frames :120
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\117.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\118.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\119.jpg
# Frames :121
# Frames :122
# Frames :123
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\120.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\121.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\122.jpg
# Frames :124
# Frames :125
# Frames :126
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\123.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\124.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\125.jpg
# Frames :127
# Frames :128
# Frames :129
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\126.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\127.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\128.jpg
# Frames :130
# Frames :131
# Frames :132
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\129.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (73.38271133951893, 33.15728589016081, 4.9385742569257545)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\130.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (73.38271133951893, 33.15728589016081, 4.9385742569257545)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\131.jpg
# Frames :133
# Frames :134
# Frames :135
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (73.38271133951893, 33.15728589016081, 4.9385742569257545)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\132.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\133.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\134.jpg
# Frames :136
# Frames :137
# Frames :138
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\135.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\136.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\137.jpg
# Frames :139
# Frames :140
# Frames :141
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\138.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\139.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\140.jpg
# Frames :142
# Frames :143
# Frames :144
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\141.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\142.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\143.jpg
# Frames :145
# Frames :146
# Frames :147
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\144.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# ...
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8231.jpg
# Frames :8233
# Frames :8234
# Frames :8235
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8232.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8233.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8234.jpg
# Frames :8236
# Frames :8237
# Frames :8238
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8235.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8236.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8237.jpg
# Frames :8239
# Frames :8240
# Frames :8241
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8238.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8239.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8240.jpg
# Frames :8242
# Frames :8243
# Frames :8244
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8241.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8242.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8243.jpg
# Frames :8245
# Frames :8246
# Frames :8247
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8244.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8245.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8246.jpg
# Frames :8248
# Frames :8249
# Frames :8250
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8247.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8248.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8249.jpg
# Frames :8251
# Frames :8252
# Frames :8253
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8250.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8251.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8252.jpg
# Frames :8254
# Frames :8255
# Frames :8256
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8253.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8254.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8255.jpg
# Frames :8257
# Frames :8258
# Frames :8259
# Predicted
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8256.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8257.jpg
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (9.958969724385001, 43.30675698896507, 223.92633837450035)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# (52.135323681536946, 223.9199462796911, 6.983836265471171)
# (77.09480602111914, 37.42275215836383, 23.54634166604344)
# writing to file:g:\Mi unidad\Cleansea\v2-IBPRIA\Cleansea\Mask_RCNN-Cleansea_DevOPS\detect\8258.jpg

# %% [markdown]
# ### Generation of video

# %%
import glob
import os

images = list(glob.iglob(os.path.join(VIDEO_SAVE_DIR, '*.*')))
# Sort the images by integer index
images = sorted(images, key=lambda x: float(os.path.split(x)[1][:-3]))

outvid = os.path.join(VIDEO_SAVE_DIR, "detection.mp4")
make_video(outvid, images, fps=30)
# Out:
# <VideoWriter 000002666A187B30>

# %% [markdown]
# ## Clean detection folder

# %%
detection_folder = os.listdir(VIDEO_SAVE_DIR)

for item in detection_folder:
    if item.endswith(".jpg"):
        os.remove(os.path.join(VIDEO_SAVE_DIR, item))
